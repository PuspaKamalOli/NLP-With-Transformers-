# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 49.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 100.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.6 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
qa=pipeline('question-answering')
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
context='Today I went to the store to purchase a cartoon of milk.'
question='what did I buy'

# %%
qa(context=context,question=question)
# Out:
# {'score': 0.48195159435272217,
#  'start': 38,
#  'end': 55,
#  'answer': 'a cartoon of milk'}

# %%
context="Albert Einstein (1879-1955) was a German-born physicist and one of the most influential scientists of the 20th century. He is best known for his theory of relativity, which revolutionized our understanding of space, time, and gravity. Einstein's equation E=mc², which relates energy (E) to mass (m) and the speed of light (c), is one of the most famous equations in physics."+\
"Einstein was born in Ulm, in the Kingdom of Württemberg in the German Empire. He showed an early aptitude for mathematics and physics, and after completing his education, he worked as a patent examiner at the Swiss Patent Office in Bern. During this time, he developed his theories on relativity and made significant contributions to the field of theoretical physics."+\
"In 1905, Einstein published four groundbreaking papers, including the special theory of relativity, which introduced the concept that the laws of physics are the same for all observers, regardless of their relative motion. This theory challenged the prevailing understanding of space and time and led to the famous equation E=mc²."+\
"In 1915, Einstein presented the general theory of relativity, which extended the principles of special relativity to include gravity. According to general relativity, gravity is not a force but rather a curvature of spacetime caused by mass and energy. This theory was confirmed by observations of the bending of light during a solar eclipse in 1919 and has since been supported by various experiments."+\
"Einstein's work also contributed to the development of quantum mechanics, particularly through his exploration of the photoelectric effect, for which he received the Nobel Prize in Physics in 1921. However, he is most renowned for his contributions to the theory of relativity and his profound impact on our understanding of the universe."+\
"Beyond his scientific accomplishments, Einstein was an outspoken advocate for civil rights, pacif"

question="When  was Einstein born?"
qa(context=context,question=question)
# Out:
# {'score': 0.9909290671348572, 'start': 17, 'end': 21, 'answer': '1879'}

# %%
question="what was Einstein known for?"
qa(context=context,question=question)
# Out:
# {'score': 0.3311750888824463,
#  'start': 145,
#  'end': 165,
#  'answer': 'theory of relativity'}

# %%
question ='what did he do in 1905,explain?'
qa(context=context,question=question)
# Out:
# {'score': 0.22019889950752258,
#  'start': 759,
#  'end': 795,
#  'answer': 'published four groundbreaking papers'}

# %%
question="what is paper made of?"
qa(context=context,question=question)
# Out:
# {'score': 0.00032837517210282385,
#  'start': 811,
#  'end': 839,
#  'answer': 'special theory of relativity'}
